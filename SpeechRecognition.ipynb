# %%
# !pip install gTTS
# Out:
# Requirement already satisfied: gTTS in c:\users\bruno.dorea\anaconda3\envs\dio-live-iot\lib\site-packages (2.2.4)
# Requirement already satisfied: requests in c:\users\bruno.dorea\anaconda3\envs\dio-live-iot\lib\site-packages (from gTTS) (2.28.1)
# Requirement already satisfied: click in c:\users\bruno.dorea\anaconda3\envs\dio-live-iot\lib\site-packages (from gTTS) (8.1.3)
# Requirement already satisfied: six in c:\users\bruno.dorea\anaconda3\envs\dio-live-iot\lib\site-packages (from gTTS) (1.16.0)
# Requirement already satisfied: colorama in c:\users\bruno.dorea\anaconda3\envs\dio-live-iot\lib\site-packages (from click->gTTS) (0.4.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bruno.dorea\anaconda3\envs\dio-live-iot\lib\site-packages (from requests->gTTS) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bruno.dorea\anaconda3\envs\dio-live-iot\lib\site-packages (from requests->gTTS) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\bruno.dorea\anaconda3\envs\dio-live-iot\lib\site-packages (from requests->gTTS) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\bruno.dorea\anaconda3\envs\dio-live-iot\lib\site-packages (from requests->gTTS) (1.26.11)

# %%
from gtts import gTTS

text_to_say = "Nice to meet you, Bruno."

language = "en"

gtts_object = gTTS(text = text_to_say,
                  lang = language,
                  slow = False)

gtts_object.save("./content/gtts.wav")

# %%
from IPython.display import Audio

Audio("./content/gtts.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
french_text = "Bonjour. Je m'appelle Alexandra. Je suis programmeuse."

french_language = "fr"

french_gtts_object = gTTS(text = french_text,
                          lang = french_language,
                          slow = True)

french_gtts_object.save("./content/french.wav")

Audio("./content/french.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
